# %% [markdown]
# ## CONNECT DB

# %%
import pandas as pd
import sqlite3
import seaborn as sns

# %%
con = sqlite3.connect("olist.db")
cur = con.cursor()

# %%
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cur.fetchall())
# Out:
# [('olist_order_customer_dataset',), ('olist_order_dataset',), ('olist_order_reviews_dataset',), ('olist_order_payments_dataset',), ('olist_order_items_dataset',), ('olist_products_dataset',), ('olist_sellers_dataset',), ('olist_geolocation_dataset',), ('product_category_name_translation',)]

# %% [markdown]
# ## READ TABLE

# %%
#read table order customer

df_olist_order_customer = pd.read_sql("SELECT * FROM olist_order_customer_dataset", con)

df_olist_order_customer
# Out:
#        index                       customer_id  \
# 0          0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1          1  18955e83d337fd6b2def6b18a428ac77
# 2          2  4e7b3e00288586ebd08712fdd0374a03
# 3          3  b2b6027bc5c5109e529d4dc6358b12c3
# 4          4  4f2d8ab171c80ec8364f7c12e35b23ad
# ...      ...                               ...
# 99436  99436  17ddf5dd5d51696bb3d7c6291687be6f
# 99437  99437  e7b71a9017aa05c9a7fd292d714858e8
# 99438  99438  5e28dfe12db7fb50a4b2f691faecea5e
# 99439  99439  56b18e2166679b8a959d72dd06da27f9
# 99440  99440  274fa6071e5e17fe303b9748641082c8
#
#                      customer_unique_id  customer_zip_code_prefix  \
# 0      861eff4711a542e4b93843c6dd7febb0                     14409
# 1      290c77bc529b7ac935b93aa66c333dc3                      9790
# 2      060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3      259dac757896d24d7702b9acbbff3f3c                      8775
# ...

# %%
df_olist_order_customer.dtypes
# Out:
# index                        int64
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object

# %%
#read table product

df_olist_product = pd.read_sql("SELECT * FROM olist_products_dataset", con)

df_olist_product
# Out:
#        index                        product_id  \
# 0          0  1e9e8ef04dbcff4541ed26657ea517e5
# 1          1  3aa071139cb16b67ca9e5dea641aaa2f
# 2          2  96bd76ec8810374ed1b65e291975717f
# 3          3  cef67bcfe19066a932b7673e239eb23d
# 4          4  9dc1a7de274444849c219cff195d0b71
# ...      ...                               ...
# 32946  32946  a0b7d5a992ccda646f2d34e418fff5a0
# 32947  32947  bf4538d88321d0fd4412a93c974510e6
# 32948  32948  9a7c6041fa9592d9d9ef6cfe62a71f8c
# 32949  32949  83808703fc0706a22e264b9d75f04a2e
# 32950  32950  106392145fca363410d287a815be6de4
#
#                    product_category_name  product_name_lenght  \
# 0                             perfumaria                 40.0
# 1                                  artes                 44.0
# 2                          esporte_lazer                 46.0
# 3                                  bebes                 27.0
# 4                  utilidades_domesticas                 37.0
# ...

# %%
df_olist_product.dtypes
# Out:
# index                           int64
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
#read table seller

df_olist_seller = pd.read_sql("SELECT * FROM olist_sellers_dataset", con)

df_olist_seller
# Out:
#       index                         seller_id  seller_zip_code_prefix  \
# 0         0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1         1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2         2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3         3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4         4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...     ...                               ...                     ...
# 3090   3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091   3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092   3092  74871d19219c7d518d0090283e03c137                    4650
# 3093   3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094   3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# ...

# %%
df_olist_seller.dtypes
# Out:
# index                      int64
# seller_id                 object
# seller_zip_code_prefix     int64
# seller_city               object
# seller_state              object
# dtype: object

# %%
#read table order items

df_olist_order_items = pd.read_sql("SELECT * FROM olist_order_items_dataset", con)

df_olist_order_items
# Out:
#          index                          order_id  order_item_id  \
# 0            0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1            1  00018f77f2f0320c557190d7a144bdd3              1
# 2            2  000229ec398224ef6ca0657da4fc703e              1
# 3            3  00024acbcdf0a6daa1e931b038114c75              1
# 4            4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...        ...                               ...            ...
# 112645  112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
df_olist_order_items.dtypes
# Out:
# index                    int64
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %%
#read table product translation

df_product_translation = pd.read_sql("SELECT * FROM product_category_name_translation", con)

df_product_translation
# Out:
#     index          product_category_name product_category_name_english
# 0       0                   beleza_saude                 health_beauty
# 1       1         informatica_acessorios         computers_accessories
# 2       2                     automotivo                          auto
# 3       3                cama_mesa_banho                bed_bath_table
# 4       4               moveis_decoracao               furniture_decor
# ..    ...                            ...                           ...
# 66     66                         flores                       flowers
# 67     67             artes_e_artesanato         arts_and_craftmanship
# 68     68                fraldas_higiene           diapers_and_hygiene
# 69     69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70     70             seguros_e_servicos         security_and_services
#
# [71 rows x 3 columns]

# %%
#read table olist orders
df_olist_orders = pd.read_sql("SELECT * FROM olist_order_dataset", con)
df_olist_orders
# Out:
#        index                          order_id  \
# 0          0  e481f51cbdc54678b7cc49136f2d6af7
# 1          1  53cdb2fc8bc7dce0b6741e2150273451
# 2          2  47770eb9100c2d0c44946d9cf07ec65d
# 3          3  949d5b44dbf5de918fe9c16f97b45f8a
# 4          4  ad21c59c0840e6cb83a9ceb5573f8159
# ...      ...                               ...
# 99436  99436  9c5dedf39a927c1b2549525ed64a053c
# 99437  99437  63943bddc261676b46f01ca7ac2f7bd8
# 99438  99438  83c1379a015df1e13d02aae0204711ab
# 99439  99439  11c177c8e97725db2631073c19f07b62
# 99440  99440  66dea50a8b16d9b4dee7af250b4be1a5
#
#                             customer_id order_status order_purchase_timestamp  \
# 0      9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 1      b0830fb4747a6c6d20dea0b8c802d7ef    delivered      2018-07-24 20:41:37
# 2      41ce2a54c0b03bf3443c3d931a367089    delivered      2018-08-08 08:38:49
# 3      f88197465ea7920adcdbec7375364d82    delivered      2017-11-18 19:28:06
# ...

# %% [markdown]
# ## COMBINE AND FILTER TABLE

# %% [markdown]
# #### DATA PRODUK

# %%
#Menggabungkan tabel data produk dengan translasi nama produk berbahasa inggris
data_produk = pd.merge(df_olist_product, df_product_translation, on = "product_category_name", how = "left")
data_produk
# Out:
#        index_x                        product_id  \
# 0            0  1e9e8ef04dbcff4541ed26657ea517e5
# 1            1  3aa071139cb16b67ca9e5dea641aaa2f
# 2            2  96bd76ec8810374ed1b65e291975717f
# 3            3  cef67bcfe19066a932b7673e239eb23d
# 4            4  9dc1a7de274444849c219cff195d0b71
# ...        ...                               ...
# 32946    32946  a0b7d5a992ccda646f2d34e418fff5a0
# 32947    32947  bf4538d88321d0fd4412a93c974510e6
# 32948    32948  9a7c6041fa9592d9d9ef6cfe62a71f8c
# 32949    32949  83808703fc0706a22e264b9d75f04a2e
# 32950    32950  106392145fca363410d287a815be6de4
#
#                    product_category_name  product_name_lenght  \
# 0                             perfumaria                 40.0
# 1                                  artes                 44.0
# 2                          esporte_lazer                 46.0
# 3                                  bebes                 27.0
# ...

# %%
#filter kolom tabel yang akan digunakan
product_index_columns = [1, 11, 6, 7, 9, 8]
data_produk = data_produk.iloc[0:, product_index_columns]

#Mengubah header tabel
data_produk.columns = ["Product ID", "Nama Produk", "Berat (gr)", "Panjang (cm)", "Lebar (cm)", "Tinggi (cm)"]
data_produk
# Out:
#                              Product ID                Nama Produk  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                  perfumery
# 1      3aa071139cb16b67ca9e5dea641aaa2f                        art
# 2      96bd76ec8810374ed1b65e291975717f             sports_leisure
# 3      cef67bcfe19066a932b7673e239eb23d                       baby
# 4      9dc1a7de274444849c219cff195d0b71                 housewares
# ...                                 ...                        ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0            furniture_decor
# 32947  bf4538d88321d0fd4412a93c974510e6  construction_tools_lights
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c             bed_bath_table
# 32949  83808703fc0706a22e264b9d75f04a2e      computers_accessories
# 32950  106392145fca363410d287a815be6de4             bed_bath_table
#
#        Berat (gr)  Panjang (cm)  Lebar (cm)  Tinggi (cm)
# 0           225.0          16.0        14.0         10.0
# ...

# %% [markdown]
# #### CUSTOMER

# %%
#filter kolom tabel yang akan digunakan
customer_index_columns = [1, 4, 5]
customer = df_olist_order_customer.iloc[0:, customer_index_columns]

#Mengubah header tabel
customer.columns = ["Customer ID", "Kota", "Kode Provinsi"]
customer
# Out:
#                             Customer ID                   Kota Kode Provinsi
# 0      06b8999e2fba1a1fbc88172c00ba8bc7                 franca            SP
# 1      18955e83d337fd6b2def6b18a428ac77  sao bernardo do campo            SP
# 2      4e7b3e00288586ebd08712fdd0374a03              sao paulo            SP
# 3      b2b6027bc5c5109e529d4dc6358b12c3        mogi das cruzes            SP
# 4      4f2d8ab171c80ec8364f7c12e35b23ad               campinas            SP
# ...                                 ...                    ...           ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f              sao paulo            SP
# 99437  e7b71a9017aa05c9a7fd292d714858e8        taboao da serra            SP
# 99438  5e28dfe12db7fb50a4b2f691faecea5e              fortaleza            CE
# 99439  56b18e2166679b8a959d72dd06da27f9                 canoas            RS
# 99440  274fa6071e5e17fe303b9748641082c8                  cotia            SP
#
# [99441 rows x 3 columns]

# %% [markdown]
# #### SELLER

# %%
#filter kolom tabel yang akan digunakan
seller_index_columns = [1, 3, 4]
seller = df_olist_seller.iloc[0:, seller_index_columns]

#Mengubah header tabel
seller.columns = ["Seller ID", "Kota", "Kode Provinsi"]
seller
# Out:
#                              Seller ID               Kota Kode Provinsi
# 0     3442f8959a84dea7ee197c632cb2df15           campinas            SP
# 1     d1b65fc7debc3361ea86b5f14c68d2e2         mogi guacu            SP
# 2     ce3ad9de960102d0677a81f5d0bb7b2d     rio de janeiro            RJ
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3          sao paulo            SP
# 4     51a04a8a6bdcb23deccc82b0b80742cf  braganca paulista            SP
# ...                                ...                ...           ...
# 3090  98dddbc4601dd4443ca174359b237166            sarandi            PR
# 3091  f8201cab383e484733266d1906e2fdfa            palhoca            SC
# 3092  74871d19219c7d518d0090283e03c137          sao paulo            SP
# 3093  e603cf3fec55f8697c9059638d6c8eb5            pelotas            RS
# 3094  9e25199f6ef7e7c347120ff175652c3b            taubate            SP
#
# [3095 rows x 3 columns]

# %% [markdown]
# #### ORDER

# %%
#Menggabungkan tabel order dengan order items untuk mendapatkan kolom customer id
order = pd.merge(df_olist_order_items, df_olist_orders, on = "order_id", how = "left")
order
# Out:
#         index_x                          order_id  order_item_id  \
# 0             0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1             1  00018f77f2f0320c557190d7a144bdd3              1
# 2             2  000229ec398224ef6ca0657da4fc703e              1
# 3             3  00024acbcdf0a6daa1e931b038114c75              1
# 4             4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...         ...                               ...            ...
# 112645   112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646   112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647   112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648   112648  fffe18544ffabc95dfada21779c9644f              1
# 112649   112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
#filter kolom tabel yang akan digunakan
order_index_columns = [1, 3, 4, 9, 6, 7]
order = order.iloc[0:, order_index_columns]

#Mengubah header tabel
order.columns = ["Order ID", "Product ID", "Seller ID", "Customer ID", "Harga Produk", "Ongkos Kirim"]
order
# Out:
#                                 Order ID                        Product ID  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 112645  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 112646  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 112647  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 112648  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 112649  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
# ...

# %% [markdown]
# ## DATA CLEANSING

# %% [markdown]
# #### MISSING VALUE

# %% [markdown]
# ##### Data Produk

# %%
#Menghitung persentase missing value
data_produk.isna().sum() / len(data_produk) * 100
# Out:
# Product ID      0.000000
# Nama Produk     1.890686
# Berat (gr)      0.006070
# Panjang (cm)    0.006070
# Lebar (cm)      0.006070
# Tinggi (cm)     0.006070
# dtype: float64

# %%
#Cek tipe data
data_produk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product ID    32951 non-null  object
#  1   Nama Produk   32328 non-null  object
#  2   Berat (gr)    32949 non-null  float64
#  3   Panjang (cm)  32949 non-null  float64
#  4   Lebar (cm)    32949 non-null  float64
#  5   Tinggi (cm)   32949 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 1.5+ MB

# %%
#imputasi data yg bertipe numerik ke mediannya
data_produk["Berat (gr)"] = data_produk["Berat (gr)"].fillna(data_produk["Berat (gr)"].median())
data_produk["Panjang (cm)"] = data_produk["Panjang (cm)"].fillna(data_produk["Panjang (cm)"].median())
data_produk["Lebar (cm)"] = data_produk["Lebar (cm)"].fillna(data_produk["Lebar (cm)"].median())
data_produk["Tinggi (cm)"] = data_produk["Tinggi (cm)"].fillna(data_produk["Tinggi (cm)"].median())

#imputasi data yg bertipe object ke "unknown"
data_produk["Nama Produk"] = data_produk["Nama Produk"].fillna("unknown")

# %%
#casting tipe data
data_produk["Berat (gr)"] = data_produk["Berat (gr)"].astype("int64")
data_produk["Panjang (cm)"] = data_produk["Panjang (cm)"].astype("int64")
data_produk["Lebar (cm)"] = data_produk["Lebar (cm)"].astype("int64")
data_produk["Tinggi (cm)"] = data_produk["Tinggi (cm)"].astype("int64")

# %%
data_produk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product ID    32951 non-null  object
#  1   Nama Produk   32951 non-null  object
#  2   Berat (gr)    32951 non-null  int64
#  3   Panjang (cm)  32951 non-null  int64
#  4   Lebar (cm)    32951 non-null  int64
#  5   Tinggi (cm)   32951 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 1.5+ MB

# %%
#Cek ulang persentase missing value
data_produk.isna().sum() / len(data_produk) * 100
# Out:
# Product ID      0.0
# Nama Produk     0.0
# Berat (gr)      0.0
# Panjang (cm)    0.0
# Lebar (cm)      0.0
# Tinggi (cm)     0.0
# dtype: float64

# %% [markdown]
# ##### Customer

# %%
#Menghitung persentase missing value
customer.isna().sum() / len(customer) * 100

#aman dari missing value
# Out:
# Customer ID      0.0
# Kota             0.0
# Kode Provinsi    0.0
# dtype: float64

# %% [markdown]
# ##### Seller

# %%
#Menghitung persentase missing value
seller.isna().sum() / len(seller) * 100

#aman dari missing value
# Out:
# Seller ID        0.0
# Kota             0.0
# Kode Provinsi    0.0
# dtype: float64

# %% [markdown]
# ##### Order

# %%
#Menghitung persentase missing value
order.isna().sum() / len(order) * 100

#aman dari missing value
# Out:
# Order ID        0.0
# Product ID      0.0
# Seller ID       0.0
# Customer ID     0.0
# Harga Produk    0.0
# Ongkos Kirim    0.0
# dtype: float64

# %% [markdown]
# #### OUTLIER

# %% [markdown]
# ##### Data Produk

# %%
#Melihat statistik deskriptif tabel
data_produk.describe()
# Out:
#          Berat (gr)  Panjang (cm)    Lebar (cm)   Tinggi (cm)
# count  32951.000000  32951.000000  32951.000000  32951.000000
# mean    2276.376802     30.814725     23.196534     16.937422
# std     4281.926387     16.914005     12.078707     13.637175
# min        0.000000      7.000000      6.000000      2.000000
# 25%      300.000000     18.000000     15.000000      8.000000
# 50%      700.000000     25.000000     20.000000     13.000000
# 75%     1900.000000     38.000000     30.000000     21.000000
# max    40425.000000    105.000000    118.000000    105.000000

# %%
#Melihat persebaran data
sns.boxplot(data=data_produk, x="Berat (gr)")
# Out:
# <Axes: xlabel='Berat (gr)'>

# %%
#batas_atas = data_produk["Berat (gr)"].quantile(q=0.75) * 1.5

#data_produk.loc[data_produk["Berat (gr)"] > batas_atas, "Berat (gr)"] = data_produk["Berat (gr)"].median()

# %%
#sns.boxplot(data=data_produk, x="Berat (gr)")

# %%
#Disebabkan karena persebaran data yang skewed, maka outlier akan dibiarkan saja karena bisa menimbulkan perubahan data yang signifikan jika dilakukan imputasi

# %% [markdown]
# ##### Order

# %%
order.describe()
# Out:
#         Harga Produk   Ongkos Kirim
# count  112650.000000  112650.000000
# mean      120.653739      19.990320
# std       183.633928      15.806405
# min         0.850000       0.000000
# 25%        39.900000      13.080000
# 50%        74.990000      16.260000
# 75%       134.900000      21.150000
# max      6735.000000     409.680000

# %%
#Melihat persebaran data
sns.boxplot(data=order, x="Harga Produk")
# Out:
# <Axes: xlabel='Harga Produk'>

# %%
#Melihat persebaran data
sns.boxplot(data=order, x="Ongkos Kirim")
# Out:
# <Axes: xlabel='Ongkos Kirim'>

# %%
#Keduanya memiliki distribusi skewed

# %% [markdown]
# #### DUPLICATES

# %% [markdown]
# ##### Data Produk

# %%
#cek duplikat
data_produk[data_produk.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Product ID, Nama Produk, Berat (gr), Panjang (cm), Lebar (cm), Tinggi (cm)]
# Index: []

# %% [markdown]
# ##### Customer

# %%
#cek duplikat
customer[customer.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Kota, Kode Provinsi]
# Index: []

# %% [markdown]
# ##### Seller

# %%
#cek duplikat
seller[seller.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Seller ID, Kota, Kode Provinsi]
# Index: []

# %% [markdown]
# ##### Order

# %%
#cek duplikat
order[order.duplicated(keep=False)]
# Out:
#                                 Order ID                        Product ID  \
# 13      0008288aa423d2a3f00fcb17cd7d8719  368c6c730842d78016ad823897a372db
# 14      0008288aa423d2a3f00fcb17cd7d8719  368c6c730842d78016ad823897a372db
# 32      00143d0f86d6fbd9f9b38ab440ac16f5  e95ee6822b66ac6058e2e4aff656071a
# 33      00143d0f86d6fbd9f9b38ab440ac16f5  e95ee6822b66ac6058e2e4aff656071a
# 34      00143d0f86d6fbd9f9b38ab440ac16f5  e95ee6822b66ac6058e2e4aff656071a
# ...                                  ...                               ...
# 112635  fff8287bbae429a99bb7e8c21d151c41  bee2e070c39f3dd2f6883a17a5f0da45
# 112640  fffb9224b6fc7c43ebb0904318b10b5f  43423cdffde7fda63d0414ed38c11a73
# 112641  fffb9224b6fc7c43ebb0904318b10b5f  43423cdffde7fda63d0414ed38c11a73
# 112642  fffb9224b6fc7c43ebb0904318b10b5f  43423cdffde7fda63d0414ed38c11a73
# 112643  fffb9224b6fc7c43ebb0904318b10b5f  43423cdffde7fda63d0414ed38c11a73
#
# ...

# %%
#Menghilangkan salah satu data duplikat
order = order.drop_duplicates(keep='first')

#cek duplikat
order[order.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product ID, Seller ID, Customer ID, Harga Produk, Ongkos Kirim]
# Index: []

# %% [markdown]
# #### INCONSISTENCY

# %% [markdown]
# ##### Seller

# %%
seller["Kode Provinsi"].unique()
# Out:
# array(['SP', 'RJ', 'PE', 'PR', 'GO', 'SC', 'BA', 'DF', 'RS', 'MG', 'RN',
#        'MT', 'CE', 'PB', 'AC', 'ES', 'RO', 'PI', 'MS', 'SE', 'MA', 'AM',
#        'PA'], dtype=object)

# %%
seller["Kota"].unique()
# Out:
# array(['campinas', 'mogi guacu', 'rio de janeiro', 'sao paulo',
#        'braganca paulista', 'brejao', 'penapolis', 'curitiba', 'anapolis',
#        'itirapina', 'tubarao', 'lauro de freitas', 'imbituba', 'brasilia',
#        'porto seguro', 'guaruja', 'tabatinga', 'salto', 'tres de maio',
#        'belo horizonte', 'arapongas', 'sao bernardo do campo', 'tatui',
#        'garopaba', 'camanducaia', 'tupa', 'guarulhos',
#        'sao jose dos pinhais', 'sao ludgero', 'sao jose', 'piracicaba',
#        'porto alegre', 'congonhal', 'santo andre', 'osasco', 'valinhos',
#        'joinville', 'saquarema', 'barra velha', 'petropolis',
#        'santo antonio da patrulha', 'ponta grossa', 'santana de parnaiba',
#        'sao carlos', 'ibitinga', 'barueri', 'caxias do sul', 'araguari',
#        'contagem', 'jaragua do sul', 'lages - sc', 'bento goncalves',
#        'catanduva', 'ribeirao pires', 'jaboticabal', 'echapora', 'cotia',
# ...

# %% [markdown]
# ##### Customer

# %%
customer["Kode Provinsi"].unique()
# Out:
# array(['SP', 'SC', 'MG', 'PR', 'RJ', 'RS', 'PA', 'GO', 'ES', 'BA', 'MA',
#        'MS', 'CE', 'DF', 'RN', 'PE', 'MT', 'AM', 'AP', 'AL', 'RO', 'PB',
#        'TO', 'PI', 'AC', 'SE', 'RR'], dtype=object)

# %%
customer["Kota"].unique()
# Out:
# array(['franca', 'sao bernardo do campo', 'sao paulo', ...,
#        'monte bonito', 'sao rafael', 'eugenio de castro'], dtype=object)

# %% [markdown]
# ## ANALYSIS

# %% [markdown]
# #### TABEL

# %%
data_produk
# Out:
#                              Product ID                Nama Produk  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                  perfumery
# 1      3aa071139cb16b67ca9e5dea641aaa2f                        art
# 2      96bd76ec8810374ed1b65e291975717f             sports_leisure
# 3      cef67bcfe19066a932b7673e239eb23d                       baby
# 4      9dc1a7de274444849c219cff195d0b71                 housewares
# ...                                 ...                        ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0            furniture_decor
# 32947  bf4538d88321d0fd4412a93c974510e6  construction_tools_lights
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c             bed_bath_table
# 32949  83808703fc0706a22e264b9d75f04a2e      computers_accessories
# 32950  106392145fca363410d287a815be6de4             bed_bath_table
#
#        Berat (gr)  Panjang (cm)  Lebar (cm)  Tinggi (cm)
# 0             225            16          14           10
# ...

# %%
seller
# Out:
#                              Seller ID               Kota Kode Provinsi
# 0     3442f8959a84dea7ee197c632cb2df15           campinas            SP
# 1     d1b65fc7debc3361ea86b5f14c68d2e2         mogi guacu            SP
# 2     ce3ad9de960102d0677a81f5d0bb7b2d     rio de janeiro            RJ
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3          sao paulo            SP
# 4     51a04a8a6bdcb23deccc82b0b80742cf  braganca paulista            SP
# ...                                ...                ...           ...
# 3090  98dddbc4601dd4443ca174359b237166            sarandi            PR
# 3091  f8201cab383e484733266d1906e2fdfa            palhoca            SC
# 3092  74871d19219c7d518d0090283e03c137          sao paulo            SP
# 3093  e603cf3fec55f8697c9059638d6c8eb5            pelotas            RS
# 3094  9e25199f6ef7e7c347120ff175652c3b            taubate            SP
#
# [3095 rows x 3 columns]

# %%
customer
# Out:
#                             Customer ID                   Kota Kode Provinsi
# 0      06b8999e2fba1a1fbc88172c00ba8bc7                 franca            SP
# 1      18955e83d337fd6b2def6b18a428ac77  sao bernardo do campo            SP
# 2      4e7b3e00288586ebd08712fdd0374a03              sao paulo            SP
# 3      b2b6027bc5c5109e529d4dc6358b12c3        mogi das cruzes            SP
# 4      4f2d8ab171c80ec8364f7c12e35b23ad               campinas            SP
# ...                                 ...                    ...           ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f              sao paulo            SP
# 99437  e7b71a9017aa05c9a7fd292d714858e8        taboao da serra            SP
# 99438  5e28dfe12db7fb50a4b2f691faecea5e              fortaleza            CE
# 99439  56b18e2166679b8a959d72dd06da27f9                 canoas            RS
# 99440  274fa6071e5e17fe303b9748641082c8                  cotia            SP
#
# [99441 rows x 3 columns]

# %%
order
# Out:
#                                 Order ID                        Product ID  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 112645  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 112646  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 112647  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 112648  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 112649  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
# ...

# %% [markdown]
# #### OBJECTIVE ANALYSIS

# %% [markdown]
# ##### 1. Jumlah Customer yang tinggal di daerah Kota dan Provinsi tertentu

# %%
customer["Kode Provinsi"].value_counts()
# Out:
# Kode Provinsi
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: count, dtype: int64

# %%
customer["Kota"].value_counts()
# Out:
# Kota
# sao paulo            15540
# rio de janeiro        6882
# belo horizonte        2773
# brasilia              2131
# curitiba              1521
#                      ...
# bequimao                 1
# andarai                  1
# vargem grande            1
# curvelandia              1
# eugenio de castro        1
# Name: count, Length: 4119, dtype: int64

# %% [markdown]
# ##### 2. Jumlah Seller yang tinggal di daerah Kota dan Provinsi tertentu

# %%
seller["Kode Provinsi"].value_counts()
# Out:
# Kode Provinsi
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# RN       5
# MS       5
# MT       4
# RO       2
# SE       2
# PI       1
# AC       1
# MA       1
# AM       1
# PA       1
# Name: count, dtype: int64

# %%
seller["Kota"].value_counts()
# Out:
# Kota
# sao paulo              694
# curitiba               127
# rio de janeiro          96
# belo horizonte          68
# ribeirao preto          52
#                       ...
# taruma                   1
# s jose do rio preto      1
# domingos martins         1
# messias targino          1
# leme                     1
# Name: count, Length: 611, dtype: int64

# %% [markdown]
# ##### 3. Informasi tentang dimensi produk yang terjual

# %%
#Menghitung volume produk
data_produk["Volume (cm3)"] = data_produk["Panjang (cm)"] * data_produk["Lebar (cm)"] * data_produk["Tinggi (cm)"]

data_produk
# Out:
#                              Product ID                Nama Produk  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                  perfumery
# 1      3aa071139cb16b67ca9e5dea641aaa2f                        art
# 2      96bd76ec8810374ed1b65e291975717f             sports_leisure
# 3      cef67bcfe19066a932b7673e239eb23d                       baby
# 4      9dc1a7de274444849c219cff195d0b71                 housewares
# ...                                 ...                        ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0            furniture_decor
# 32947  bf4538d88321d0fd4412a93c974510e6  construction_tools_lights
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c             bed_bath_table
# 32949  83808703fc0706a22e264b9d75f04a2e      computers_accessories
# 32950  106392145fca363410d287a815be6de4             bed_bath_table
#
#        Berat (gr)  Panjang (cm)  Lebar (cm)  Tinggi (cm)  Volume (cm3)
# 0             225            16          14           10          2240
# ...

# %%
#Filter agar Product ID tidak ikut grouping
data_produk_grouping = data_produk.iloc[0:, 1:]

data_produk_grouping.groupby("Nama Produk").agg(['max', 'min', 'mean', 'sum'])
# Out:
#                            Berat (gr)                            Panjang (cm)  \
#                                   max  min         mean      sum          max
# Nama Produk
# agro_industry_and_commerce      30000   50  5263.405405   389492           99
# air_conditioning                23300  100  4459.959677   553035          105
# art                             15400  100  1691.763636    93047          100
# arts_and_craftmanship            6850  100  1164.578947    22127          105
# audio                            6663  100   641.637931    37215           40
# ...                               ...  ...          ...      ...          ...
# tablets_printing_image           1100  100   381.444444     3433           60
# telephony                        8100   50   236.506173   268198           40
# toys                            30000   50  1869.356485  2637662          105
# unknown                         30000   50  2248.603531  1400880          105
# ...

# %% [markdown]
# ##### 4. Korelasi Ongkos Kirim dengan Lokasi Tempat Tinggal Seller dan Customer

# %%
#merge tabel order dengan seller
korelasi_ongkir = pd.merge(order, seller, on="Seller ID", how="left")
korelasi_ongkir
# Out:
#                                 Order ID                        Product ID  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 102420  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 102421  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 102422  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 102423  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 102424  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
# ...

# %%
#merge tabel order dengan customer
korelasi_ongkir = pd.merge(korelasi_ongkir, customer, on="Customer ID", how="left")
korelasi_ongkir
# Out:
#                                 Order ID                        Product ID  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 102420  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 102421  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 102422  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 102423  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 102424  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
# ...

# %%
#Filter kolom yang dibutuhkan
korelasi_ongkir_index = [6, 7, 8, 9, 4, 5]
korelasi_ongkir = korelasi_ongkir.iloc [0:, korelasi_ongkir_index]

#Rename header
korelasi_ongkir.columns = ["Kota Seller", "Kode Provinsi Seller", "Kota Customer", "Kode Provinsi Customer", "Harga Produk", 'Ongkos Kirim']
korelasi_ongkir
# Out:
#           Kota Seller Kode Provinsi Seller          Kota Customer  \
# 0       volta redonda                   SP  campos dos goytacazes
# 1           sao paulo                   SP        santa fe do sul
# 2       borda da mata                   MG          para de minas
# 3              franca                   SP                atibaia
# 4              loanda                   PR        varzea paulista
# ...               ...                  ...                    ...
# 102420         itajai                   SC               sao luis
# 102421      sao paulo                   SP               curitiba
# 102422       curitiba                   PR              sao paulo
# 102423      sao paulo                   SP                vinhedo
# 102424       ibitinga                   SP               botucatu
#
#        Kode Provinsi Customer  Harga Produk  Ongkos Kirim
# 0                          RJ         58.90         13.29
# ...

# %%
sns.boxplot(data=korelasi_ongkir, x="Harga Produk", y="Kode Provinsi Seller")
# Out:
# <Axes: xlabel='Harga Produk', ylabel='Kode Provinsi Seller'>

# %%
sns.boxplot(data=korelasi_ongkir, x="Harga Produk", y="Kode Provinsi Customer")
# Out:
# <Axes: xlabel='Harga Produk', ylabel='Kode Provinsi Customer'>

# %%
sns.boxplot(data=korelasi_ongkir, x="Ongkos Kirim", y="Kode Provinsi Seller")
# Out:
# <Axes: xlabel='Ongkos Kirim', ylabel='Kode Provinsi Seller'>

# %%
sns.boxplot(data=korelasi_ongkir, x="Ongkos Kirim", y="Kode Provinsi Customer")
# Out:
# <Axes: xlabel='Ongkos Kirim', ylabel='Kode Provinsi Customer'>

# %% [markdown]
# ##### 5. Pengaruh Volume dan Berat Barang terhadap Ongkos Kirim

# %%
#merge tabel order dengan data produk
pengaruh_ongkir = pd.merge(order, data_produk, on="Product ID", how="left")
pengaruh_ongkir
# Out:
#                                 Order ID                        Product ID  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 102420  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 102421  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 102422  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 102423  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 102424  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
# ...

# %%
#Filter kolom yang dibutuhkan
pengaruh_ongkir_index = [7, 11, 5]
pengaruh_ongkir = pengaruh_ongkir.iloc [0:, pengaruh_ongkir_index]

pengaruh_ongkir
# Out:
#         Berat (gr)  Volume (cm3)  Ongkos Kirim
# 0              650          3528         13.29
# 1            30000         60000         19.93
# 2             3050         14157         17.87
# 3              200          2400         12.79
# 4             3750         42000         18.14
# ...            ...           ...           ...
# 102420       10150         53400         43.41
# 102421        8950         44460         36.53
# 102422         967          9576         16.95
# 102423         100          8000          8.72
# 102424         600          1710         12.79
#
# [102425 rows x 3 columns]

# %%
#Scatterplot pengaruh berat dan ongkir
sns.scatterplot(data=pengaruh_ongkir, x="Berat (gr)", y="Ongkos Kirim")
# Out:
# <Axes: xlabel='Berat (gr)', ylabel='Ongkos Kirim'>

# %%
#Scatterplot pengaruh volume dan ongkir
sns.scatterplot(data=pengaruh_ongkir, x="Volume (cm3)", y="Ongkos Kirim")
# Out:
# <Axes: xlabel='Volume (cm3)', ylabel='Ongkos Kirim'>

# %% [markdown]
# ##### 6. Pengaruh Volume dan Berat Barang terhadap Harga Barang

# %%
#merge tabel order dengan data produk
pengaruh_harga_barang = pd.merge(order, data_produk, on="Product ID", how="left")
pengaruh_harga_barang
# Out:
#                                 Order ID                        Product ID  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 102420  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 102421  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 102422  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 102423  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 102424  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
# ...

# %%
#Filter kolom yang dibutuhkan
pengaruh_harga_index = [7, 11, 4]
pengaruh_harga_barang = pengaruh_harga_barang.iloc [0:, pengaruh_harga_index]

pengaruh_harga_barang
# Out:
#         Berat (gr)  Volume (cm3)  Harga Produk
# 0              650          3528         58.90
# 1            30000         60000        239.90
# 2             3050         14157        199.00
# 3              200          2400         12.99
# 4             3750         42000        199.90
# ...            ...           ...           ...
# 102420       10150         53400        299.99
# 102421        8950         44460        350.00
# 102422         967          9576         99.90
# 102423         100          8000         55.99
# 102424         600          1710         43.00
#
# [102425 rows x 3 columns]

# %%
#Scatterplot pengaruh berat dan harga
sns.scatterplot(data=pengaruh_harga_barang, x="Berat (gr)", y="Harga Produk")
# Out:
# <Axes: xlabel='Berat (gr)', ylabel='Harga Produk'>

# %%
#Scatterplot pengaruh volume dan harga
sns.scatterplot(data=pengaruh_harga_barang, x="Volume (cm3)", y="Harga Produk")
# Out:
# <Axes: xlabel='Volume (cm3)', ylabel='Harga Produk'>
